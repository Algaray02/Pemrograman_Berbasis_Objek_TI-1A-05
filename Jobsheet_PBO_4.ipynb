# %% [markdown]
# <a href="https://colab.research.google.com/github/Algaray02/Pemrograman_Berbasis_Objek_TI-1A-05/blob/main/Jobsheet_PBO_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# JOBSHEET 04: MEMAHAMI PEWARISAN (INHERITANCE) DALAM PYTHON

# %% [markdown]
# Praktikum 01: Inheritance Dasar

# %%
class Kendaraan:
   def __init__(self, merk):
      self.merk = merk

   def mulai_mesin(self):
      print(f'Mesin kendaraan {self.merk} dinyalakan.')


class Mobil(Kendaraan):
   def __init__(self, merk, warna):
      self.merk = merk
      self.warna = warna

   def info_mobil(self):
      print(f'Ini adalah mobil {self.merk} berwarna {self.warna}.')


if __name__ == "__main__":
   mobil_tesla = Mobil("Tesla Model S", "Biru")
   mobil_tesla.info_mobil()
   mobil_tesla.mulai_mesin()

   print(f"merk mobil: {mobil_tesla.merk}")
# Out:
# Ini adalah mobil Tesla Model S berwarna Biru.
# Mesin kendaraan Tesla Model S dinyalakan.
# merk mobil: Tesla Model S

# %% [markdown]
# Praktikum 02: Menggunakan super() dalam konstruktor

# %%
class Person:
   def __init__(self, nama, usia):
      print(f'(Memanggil __init__ Person untuk "{nama}")')
      self.nama = nama
      self.usia = usia

   def perkenalan_diri(self):
      print(f'Halo, nama saya {self.nama}, usia saya {self.usia} tahun.')


class Student(Person):
   def __init__(self, nama, usia, student_id, jurusan):
      super().__init__(nama, usia)
      print(f'(memanggil __init__ Student untuk "{nama})')
      self.student_id = student_id
      self.jurusan = jurusan
      print(f'(Inisialisasi atribut Student selesai untuk "{nama})')

   def info_akademik(self):
      print(f"ID Mahasiswa: {self.student_id}")
      print(f"Jurusan: {self.jurusan}")

   def perkenalan_diri(self):
      super().perkenalan_diri()
      print(f'Saya adalah mahasiswa dengan ID {self.student_id}, jurusan {self.jurusan}.')


# Kode Utama--
if __name__ == "__main__":
   dosen = Person('Pak Prayit', 45)
   print("="*10)
   dosen.perkenalan_diri()
   print("\n" + "-"*20 + "\n")


   # Buat objek student
   Mahasiswa = Student("Alfin", 19, "MHS005", "Teknologi Rekayasa Komputer")
   print('='*10)
   Mahasiswa.perkenalan_diri()
   print('='*10)
   Mahasiswa.info_akademik()

   print(f"\nUsia Mahasiswa {Mahasiswa.nama}: {Mahasiswa.usia}")
# Out:
# (Memanggil __init__ Person untuk "Pak Prayit")
# ...
# Halo, nama saya Pak Prayit, usia saya 45 tahun.
#
# --------------------
#
# (Memanggil __init__ Person untuk "Alfin")
# (memanggil __init__ Student untuk "Alfin)
# (Inisialisasi atribut Student selesai untuk "Alfin)
# ...
# Halo, nama saya Alfin, usia saya 19 tahun.
# Saya adalah mahasiswa dengan ID MHS005, jurusan Teknologi Rekayasa Komputer.
# ...
# ID Mahasiswa: MHS005
# Jurusan: Teknologi Rekayasa Komputer
#
# Usia Mahasiswa Alfin: 19

# %% [markdown]
# Praktikum 03: Method Overriding dan super()

# %%
class Hewan:
   def __init__(self, nama):
      self.nama = nama

   def bersuara(self):
      print(f'{self.nama} mengeluarkan suara generik.')

   def tampilkan_info(self):
      print(f'Ini adalah hewan bernama {self.nama}.')


class Kucing(Hewan):
   def __init__(self, nama, ras):
      super().__init__(nama)
      self.ras = ras

   def bersuara(self):
      print(f'{self.nama} (Kucing) mengeong: Meeow!')

   def tampilkan_info(self):
      super().tampilkan_info()
      print(f'Ini adalah Kucing ras {self.ras}.')


if __name__ == "__main__":
   hewan_umum = Hewan("Makhluk")
   kucing_persia = Kucing("Puspus", "Persia")

   print("Info Hewan Umum:")
   hewan_umum.tampilkan_info()
   hewan_umum.bersuara()
   print('='*20)

   print('\nInfo Kucing Persia:')
   kucing_persia.tampilkan_info()
   kucing_persia.bersuara()
# Out:
# Info Hewan Umum:
# Ini adalah hewan bernama Makhluk.
# Makhluk mengeluarkan suara generik.
# ...
#
# Info Kucing Persia:
# Ini adalah hewan bernama Puspus.
# Ini adalah Kucing ras Persia.
# Puspus (Kucing) mengeong: Meeow!

# %% [markdown]
# Praktikum 04: Multi-level Inheritance (Pewarisan Bertingkat)

# %%
# induk lvl 1
class Organisme:
   def __init__(self, nama):
      self.nama = nama
      print(f'Organisme "{self.nama}" diciptakan.')

   def bernapas(self):
      print(f'{self.nama} sedang bernapas.')


# anak lvl 1
class Hewan(Organisme):
   def __init__(self, nama, jenis_makanan):
      super().__init__(nama)
      self.jenis_makanan = jenis_makanan
      print(f'Hewan "{self.nama}" adalah {self.jenis_makanan}.')

   def bergerak(self):
      print(f'{self.nama} sedang bergerak.')

# anak lvl 2
class Mamalia(Hewan):
   def __init__(self, nama, jenis_makanan, jumlah_kaki):
      super().__init__(nama, jenis_makanan)
      self.jumlah_kaki = jumlah_kaki
      print(f'Mamalia "{self.nama}" memiliki {self.jumlah_kaki} kaki.')

   def menyusui(self):
      print(f'{self.nama} sedang menyusui.')



if __name__ == "__main__":
   kucing = Mamalia("Kucing Persia", "Karnivora", 4)
   print('='*20)

   kucing.menyusui()
   kucing.bergerak()
   print(f'Jenis makanan: {kucing.jenis_makanan}')

   kucing.bernapas()
   print(f'Nama organisme: {kucing.nama}')
# Out:
# Organisme "Kucing Persia" diciptakan.
# Hewan "Kucing Persia" adalah Karnivora.
# Mamalia "Kucing Persia" memiliki 4 kaki.
# ...
# Kucing Persia sedang menyusui.
# Kucing Persia sedang bergerak.
# Jenis makanan: Karnivora
# Kucing Persia sedang bernapas.
# Nama organisme: Kucing Persia

# %% [markdown]
# Praktikum 05: Hierarchical Inheritance

# %%
import locale

try:
   locale.setlocale(locale.LC_ALL, 'id_ID.UTF-8')
except locale.Error:
   print('Locale id_ID.UTF-8 tidak tersedia, menggunakan default.')

def rupiah(angka):
   return locale.currency(angka, grouping=True, symbol='Rp ')


# induk
class Pegawai:
   def __init__(self, nama, id_pegawai, gaji_pokok):
      self.nama = nama
      self.id_pegawai = id_pegawai
      self.gaji_pokok = gaji_pokok

   def hitung_gaji(self):
      return self.gaji_pokok

   def tampilkan_info(self):
      print(f'ID: {self.id_pegawai}, Nama: {self.nama}')
      print(f'Gaji Pokok: {rupiah(self.gaji_pokok)}')


# anak 1
class Manager(Pegawai):
   def __init__(self, nama, id_pegawai, gaji_pokok, tunjangan_jabatan):
      super().__init__(nama, id_pegawai, gaji_pokok)
      self.tunjangan_jabatan = tunjangan_jabatan

   def hitung_gaji(self):
      gaji_total = super().hitung_gaji() + self.tunjangan_jabatan
      return gaji_total

   def tampilkan_info(self):
      print('---Info Manager---')
      super().tampilkan_info()
      print(f'Tunjangan Jabatan: {rupiah(self.tunjangan_jabatan)}')
      print(f'Total Gaji: {rupiah(self.hitung_gaji())}')


# anak 2
class StaffTeknis(Pegawai):
   def __init__(self, nama, id_pegawai, gaji_pokok, keahlian, bonus_keahlian):
      super().__init__(nama, id_pegawai, gaji_pokok)
      self.keahlian = keahlian
      self.bonus_keahlian = bonus_keahlian

   def hitung_gaji(self):
      gaji_total =  super().hitung_gaji() + self.bonus_keahlian
      return gaji_total

   def tampilkan_info(self):
      print('---Info Staff Teknis---')
      super().tampilkan_info()
      print(f'Keahlian: {self.keahlian}')
      print(f'Total Gaji: {rupiah(self.hitung_gaji())}')



if __name__ == "__main__":
   manager1 = Manager("Budi Santoso", "M001", 10000000, 5000000)
   staf1 = StaffTeknis("Citra Lestari", "S001", 7000000, "Python Programming", 1500000)
   pegawai_baru = Pegawai("Rian", "P005", 5000000)

   print('Menampilkan Informasi Pegawai:')
   manager1.tampilkan_info()
   print('='*40)
   staf1.tampilkan_info()
   print('='*40)

   print('\n---Info Pegawai Baru---')
   pegawai_baru.tampilkan_info()
   print(f'Total Gaji: {rupiah(pegawai_baru.hitung_gaji())}')
   print('='*40)
# Out:
# Locale id_ID.UTF-8 tidak tersedia, menggunakan default.
# Menampilkan Informasi Pegawai:
# ---Info Manager---
# ID: M001, Nama: Budi Santoso
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-f999e9b0a7ae> in <cell line: 0>()
#      67
#      68    print('Menampilkan Informasi Pegawai:')
# ---> 69    manager1.tampilkan_info()
#      70    print('='*40)
#      71    staf1.tampilkan_info()
#
# <ipython-input-6-f999e9b0a7ae> in tampilkan_info(self)
#      37    def tampilkan_info(self):
#      38       print('---Info Manager---')
# ---> 39       super().tampilkan_info()
#      40       print(f'Tunjangan Jabatan: {rupiah(self.tunjangan_jabatan)}')
#      41       print(f'Total Gaji: {rupiah(self.hitung_gaji())}')
#
# <ipython-input-6-f999e9b0a7ae> in tampilkan_info(self)
#      22    def tampilkan_info(self):
# ...

# %% [markdown]
# Praktikum 06: Memeriksa Tipe Instance dengan instance()

# %%
class BentukGeometri:
   def __init__(self, nama_bentuk):
      self.nama_bentuk = nama_bentuk
   def tampilkan_nama(self):
      print(f'Ini adalah bentuk: {self.nama_bentuk}')
   def hitung_luas(self):
      print(f'Luas {self.nama_bentuk} tidak dapat dihitung (generik).')

class PersegiPanjang(BentukGeometri):
   def __init__(self, panjang, lebar):
      super().__init__("Persegi Panjang")
      self.panjang = panjang
      self.lebar = lebar
   def hitung_luas(self):
      luas = self.panjang * self.lebar
      print(f'Luas {self.nama_bentuk}: {luas}')

class Segitiga(BentukGeometri):
   def __init__(self, alas, tinggi):
      super().__init__("Segitiga")
      self.alas = alas
      self.tinggi = tinggi
   def hitung_luas(self):
      luas = 0.5 * self.alas * self.tinggi
      print(f'Luas {self.nama_bentuk}: {luas}')


def proses_bentuk(bentuk):
   print(f'\nMemproses objek: {type(bentuk)}')

   if isinstance(bentuk, BentukGeometri):
      bentuk.tampilkan_nama()
      print('Objek ini adalah instance dari BentukGeometri (atau turunannya).')

   if isinstance(bentuk, PersegiPanjang):
      print('-> Objek ini juga instance dari PersegiPanjang.')
   elif isinstance(bentuk, Segitiga):
      print('-> Objek ini juga instance dari Segitiga.')
   else:
      print('Objek ini BUKAN instance dari BentukGeometri.')

   if isinstance(bentuk, str):
      print('Objek ini adalah string.')


# Kode Utama
if __name__ == "__main__":
   pp = PersegiPanjang(4, 3)
   seg3 = Segitiga(5, 2)
   bg = BentukGeometri("Lingkaran")
   teks = "Ini String"

   daftar_objek = [pp, seg3, bg, teks]

   for obj in daftar_objek:
      proses_bentuk(obj)

# %% [markdown]
# Penugasan

# %%
from colorama import Fore, Style

class Mahasiswa:
   def __init__(self, nama, nim, ipk):
      self.nama = nama
      self.nim = nim
      self.ipk = ipk


   def tampilkan_info(self):
      print(f'Nama          : {self.nama}')
      print(f'NIM           : {self.nim}')
      print(f'IPK           : {self.ipk}')
      self.hitung_predikat()

   def hitung_predikat(self):
      if self.ipk >= 3.5:
         return print('Predikat     : Dengan Pujian')
      elif self.ipk >= 3.0:
         return print('Predikat     : Sangat Memuaskan')
      elif self.ipk >= 2.5:
         return print('Predikat     : Memuaskan')
      elif self.ipk < 2.5:
         return print('Predikat     : Cukup')


class MahasiswaSarjana(Mahasiswa):
   def __init__(self, nama, nim, ipk, semester, sks_lulus):
      super().__init__(nama, nim, ipk)
      self.semester = semester
      self.sks_lulus = sks_lulus

   def tampilkan_info(self):
      super().tampilkan_info()
      print(f'Semester      : {self.semester}')
      print(f'SKS Lulus     : {self.sks_lulus}')

   def __del__(self):
      print(f'\n{Fore.GREEN}Data Mahasiswa Sarjana Sedang Dihapus...{Style.RESET_ALL}')


class MahasiswaMagister(Mahasiswa):
   def __init__(self, nama, nim, ipk, judul_tesis, nama_pembimbing):
      super().__init__(nama, nim, ipk)
      self.judul_tesis = judul_tesis
      self.nama_pembimbing = nama_pembimbing

   def hitung_predikat(self):
      if self.ipk >= 3.75:
         return print('Predikat    : Cumlaude')
      elif self.ipk >= 3.5:
         return print('Predikat    : Sangat Memuaskan')
      elif self.ipk >= 3:
         return print('Predikat    : Memuaskan')
      elif self.ipk < 3:
         return print('Predikat    : Tidak Ada Predikat')

   def tampilkan_info(self):
      super().tampilkan_info()
      print(f'Judul Tesis  : {self.judul_tesis}')
      print(f'Pembimbing   : {self.nama_pembimbing}')

   def __del__(self):
      print(f'\n{Fore.GREEN}Data Mahasiswa Magister Sedang Dihapus...{Style.RESET_ALL}')

def main():
   sjr = ""
   mgs = ""
   while True:
      try:
         print(f'{Fore.GREEN}{Style.BRIGHT}\n===PROGRAM PROFIL MAHASISWA==={Style.RESET_ALL}')
         print('1. Edit Data Mahasiswa')
         print('2. Tampilkan Info Mahasiswa')
         print('3. Hapus Data Mahasiswa')
         print('4. Keluar')
         ipt = int(input('Pilih Opsi(1-4): '))
      except ValueError:
         print('Input Tidak Valid!!')

      if ipt == 1:
         try:
            print(f'{Fore.BLUE}{Style.BRIGHT}\n==DATA MAHASISWA=={Style.RESET_ALL}')
            print('1. Mahasiswa Sarjana')
            print('2. Mahasiswa Magister')
            ipt1 = int(input('Pilih Opsi(1-2): '))
         except ValueError:
            print(f'{Fore.RED}Input Tidak Valid!!{Style.RESET_ALL}')

         if ipt1 == 1:
            try:
               print(f"{Fore.MAGENTA}{Style.BRIGHT}\n==MAHASISWA SARJANA=={Style.RESET_ALL}")
               nama = input('Masukkan Nama: ')
               nim = input('Masukkan NIM: ')
               ipk = float(input('Masukkan IPK: '))
               smt = int(input('Semester: '))
               sks = int(input('SKS Lulus: '))
               sjr = MahasiswaSarjana(nama, nim, ipk, smt, sks)
            except ValueError:
               print(f'{Fore.RED}Input Tidak Sesuai!!{Style.RESET_ALL}')

         elif ipt1 == 2:
            try:
               print(f"{Fore.CYAN}{Style.BRIGHT}\n==MAHASISWA MAGISTER=={Style.RESET_ALL}")
               nama = input('Masukkan Nama: ')
               nim = input('Masukkan NIM: ')
               ipk = float(input('Masukkan IPK: '))
               tss = input('Judul Tesis: ')
               pbb = input('Nama Pembimbing: ')
               mgs = MahasiswaMagister(nama, nim, ipk, tss, pbb)
            except ValueError:
               print(f'{Fore.RED}Input Tidak Sesuai!!{Style.RESET_ALL}')

      elif ipt == 2:
         if sjr and mgs:
            print(f'{Fore.MAGENTA}{Style.BRIGHT}\n===INFO MAHASISWA SARJANA==={Style.RESET_ALL}')
            sjr.tampilkan_info()
            print(f'{Fore.CYAN}{Style.BRIGHT}\n===INFO MAHASISWA MAGISTER==={Style.RESET_ALL}')
            mgs.tampilkan_info()
         elif sjr:
            print(f'{Fore.MAGENTA}{Style.BRIGHT}\n===INFO MAHASISWA SARJANA==={Style.RESET_ALL}')
            sjr.tampilkan_info()
         elif mgs:
            print(f'{Fore.CYAN}{Style.BRIGHT}\n===INFO MAHASISWA MAGISTER==={Style.RESET_ALL}')
            mgs.tampilkan_info()
         else:
            print(f"{Fore.RED}Data Mahasiswa Kosong!!{Style.RESET_ALL}")

      elif ipt == 3:
         if sjr and mgs:
            del sjr, mgs
            sjr = ""
            mgs = ""
            print(f'\n{Fore.YELLOW} Data Mahasiswa Sarjana dan Magister Berhasil Dihapus...{Style.RESET_ALL}')
         elif sjr:
            del sjr
            sjr = ""
            print(f'\n{Fore.YELLOW} Data Mahasiswa Sarjana Berhasil Dihapus...{Style.RESET_ALL}')
         elif mgs:
            del mgs
            mgs = ""
            print(f'\n{Fore.YELLOW} Data Mahasiswa Magister Berhasil Dihapus...{Style.RESET_ALL}')
         else:
            print(f'{Fore.RED}Data Mahasiswa Kosong!!{Style.RESET_ALL}')

      elif ipt == 4:
         print(f'{Fore.GREEN}Terimakasih Sudah Menggunakan Program...{Style.RESET_ALL}')
         break

      else:
         print(f'{Fore.RED}Input Tidak Valid!!{Style.RESET_ALL}')


if __name__ == "__main__":
   main()
# Out:
# ===PROGRAM PROFIL MAHASISWA===
# 1. Edit Data Mahasiswa
# 2. Tampilkan Info Mahasiswa
# 3. Hapus Data Mahasiswa
# 4. Keluar
# Pilih Opsi(1-4): 1
#
# ==DATA MAHASISWA==
# 1. Mahasiswa Sarjana
# 2. Mahasiswa Magister
# Pilih Opsi(1-2): 1
#
# ==MAHASISWA SARJANA==
# Masukkan Nama: Alfin Rozzaq Nirwana
# Masukkan NIM: 43324005
# Masukkan IPK: 3.88
# Semester: 2
# SKS Lulus: 20
#
# ===PROGRAM PROFIL MAHASISWA===
# 1. Edit Data Mahasiswa
# 2. Tampilkan Info Mahasiswa
# 3. Hapus Data Mahasiswa
# 4. Keluar
# Pilih Opsi(1-4): 2
#
# ===INFO MAHASISWA SARJANA===
# Nama          : Alfin Rozzaq Nirwana
# NIM           : 43324005
# IPK           : 3.88
# Predikat     : Dengan Pujian
# Semester      : 2
# SKS Lulus     : 20
#
# ===PROGRAM PROFIL MAHASISWA===
# 1. Edit Data Mahasiswa
# 2. Tampilkan Info Mahasiswa
# 3. Hapus Data Mahasiswa
# 4. Keluar
# Pilih Opsi(1-4): 1
#
# ==DATA MAHASISWA==
# 1. Mahasiswa Sarjana
# 2. Mahasiswa Magister
# Pilih Opsi(1-2): 2
#
# ==MAHASISWA MAGISTER==
# ...
