# %% [markdown]
# <a href="https://colab.research.google.com/github/Algaray02/Pemrograman_Berbasis_Objek_TI-1A-05/blob/main/Jobsheet_PBO-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Jobsheet 01- Dasar Bahasa Pemrograman Python

# %% [markdown]
# Praktikum 01. Tipe data dasar

# %%
# !pip install colorama
from colorama import Fore, Style

# %%
print(f'{Fore.GREEN}1. Number (int, float, complex){Style.RESET_ALL}')
# Integer (int)
angka_int = 10
print("angka_int =", angka_int, "->", type(angka_int))

# Float
angka_float = 3.14
print("angka_float =", angka_float, "->", type(angka_float))

# Complex
angka_complex = 2 + 3j
print("angka_complex =", angka_complex, "->", type(angka_complex))

print('''\nNote : Dari kode diatas dapat disimpulkan bahwa tipe data number pada python terdiri dari 3 (int, float, complex)
      Tetapi dalam python tidak perlu dideklarasikan tipe data number secara eksplisit seperti pada bahasa lainnya''')

print(f'{Fore.GREEN}\n2. Boolean{Style.RESET_ALL}')
is_active = True
print("is_active =", is_active, "->", type(is_active))

print('''\nNote : Dari kode diatas, tipe data boolean terdiri dari 2 nilai yaitu True dan False''')

print(f'{Fore.GREEN}\n3. String{Style.RESET_ALL}')
teks = "Hello, Python!"
print("teks =", teks, "->", type(teks))

print('''\nNote : Dari kode diatas, tipe data string terdiri dari kata atau kalimat yang diapit oleh tanda kutip (' atau ")''')

print(f'{Fore.GREEN}\n4. List{Style.RESET_ALL}')
# List adalah tipe data terurut dan dapat diubah (mutable)
daftar_angka = [1, 2, 3, 4, 5]
print("daftar_angka =", daftar_angka, "->", type(daftar_angka))

print('''\nNote : Dari kode diatas, tipe data list adalah kumpulan data yang sejenis dan diapit oleh tanda kurung siku ([])
      Tipe data pada list tidak harus sejenis dan dapat diubah nilainya''')

print(f'{Fore.GREEN}\n5. Tuple{Style.RESET_ALL}')
# Tuple adalah tipe data terurut tetapi tidak dapat diubah (immutable)
koordinat = (10, 20)
print("koordinat =", koordinat, "->", type(koordinat))

print('''\nNote : Dari kode diatas, tipe data tuple adalah kumpulan data sejenis yang diapit oleh tanda kurung biasa ()''')

print(f'{Fore.GREEN}\n6. Dictionary{Style.RESET_ALL}')
# Dictionary menyimpan data dalam pasangan key-value
# Dictionary menyimpan data dalam pasangan key-value
data_mahasiswa = {
   "nama": "Andi",
   "nim": "A11.2022.12345",
   "jurusan": "Teknik Informatika"
}
print("data_mahasiswa =", data_mahasiswa, "->", type(data_mahasiswa))

print('''\nNote : Dari kode diatas, tipe data dict atau dictionary adalah kumpulan data yang memiliki key-value
      Key-value dapat berupa string atau integer dan diapit oleh tanda kurung kurawal ({})''')

print(f'{Fore.GREEN}\n7. Set{Style.RESET_ALL}')
# Set adalah tipe data yang tidak terurut, unik (tiap elemen hanya muncul 1x)
himpunan_angka = {1, 2, 3, 2, 1}
print("himpunan_angka =", himpunan_angka, "->", type(himpunan_angka))

print('''\nNote : Dari kode diatas, tipe data set adalah kumpulan data yang dapat diubah dan tidak memiliki indeks
      Sama seperti dict, set juga diapit oleh tanda kurung kurawal ({})''')

print(f'{Fore.GREEN}\n8. Contoh penggunaan konversi tipe data{Style.RESET_ALL}')
nilai_str = "100"
print("\nnilai_str =", nilai_str, "->", type(nilai_str))
nilai_int = int(nilai_str)  # konversi string ke integer
print("nilai_int =", nilai_int, "->", type(nilai_int))

print('''\nNote : Dari kode diatas, tipe data integer dapat menjadi string bila penulisannya diapit oleh tanda kutip
      Untuk mengubah menjadi integer lagi dapat didefinisikan menggunakan fungsi int(nama_variabel)''')
# Out:
# 1. Number (int, float, complex)
# angka_int = 10 -> <class 'int'>
# angka_float = 3.14 -> <class 'float'>
# angka_complex = (2+3j) -> <class 'complex'>
#
# Note : Dari kode diatas dapat disimpulkan bahwa tipe data number pada python terdiri dari 3 (int, float, complex)
#       Tetapi dalam python tidak perlu dideklarasikan tipe data number secara eksplisit seperti pada bahasa lainnya
#
# 2. Boolean
# is_active = True -> <class 'bool'>
#
# Note : Dari kode diatas, tipe data boolean terdiri dari 2 nilai yaitu True dan False
#
# 3. String
# teks = Hello, Python! -> <class 'str'>
#
# Note : Dari kode diatas, tipe data string terdiri dari kata atau kalimat yang diapit oleh tanda kutip (' atau ")
#
# 4. List
# daftar_angka = [1, 2, 3, 4, 5] -> <class 'list'>
#
# Note : Dari kode diatas, tipe data list adalah kumpulan data yang sejenis dan diapit oleh tanda kurung siku ([])
#       Tipe data pada list tidak harus sejenis dan dapat diubah nilainya
#
# 5. Tuple
# ...

# %% [markdown]
# Praktikum 02. Variabel dan Operasi dasar

# %%
print(f'{Fore.GREEN}1. Pendeklarasian Variabel{Style.RESET_ALL}')
nama = "Budi"
umur = 20
tinggi = 170.5
is_student = True

print("Nama =", nama)
print("Umur =", umur)
print("Tinggi =", tinggi, "cm")
print("Mahasiswa =", is_student)

# Python tidak memerlukan deklarasi tipe data secara eksplisit.
# Tipe data variabel akan menyesuaikan nilai yang diberikan.

print('''\nNote : Dari kode diatas, deklarasi variabel pada python tidak memerlukan tipe data secara eksplisit
      Python akan menyesuaikan tipe data sesuai nilai dari variabel tersebut''')

print(f'{Fore.GREEN}\n2. Operasi Aritmetika{Style.RESET_ALL}')
a = 10
b = 3

penjumlahan = a + b      # Tambah
pengurangan = a - b      # Kurang
perkalian = a * b        # Kali
pembagian = a / b        # Bagi (hasil float)
pembagian_bulat = a // b # Bagi (bulat)
modulus = a % b          # Sisa bagi
pangkat = a ** b         # Pemangkatan

print("\nOPERASI ARITMETIKA")
print("a =", a, ", b =", b)
print("Penjumlahan =", penjumlahan)
print("Pengurangan =", pengurangan)
print("Perkalian =", perkalian)
print("Pembagian =", pembagian)
print("Pembagian Bulat =", pembagian_bulat)
print("Modulus =", modulus)
print("Pangkat =", pangkat)

print('''\nNote : Dari kode diatas, operasi aritmatika pada python terdiri dari 7 jenis...masing-masing jenis
      memiliki bentuk (operator) dan fungsi yang berbeda-beda sesuai dengan kebutuhan''')

print(f'{Fore.GREEN}\n3. Operasi Perbandingan{Style.RESET_ALL}')
# Menghasilkan nilai Boolean (True/False)
lebih_besar = a > b
kurang_dari = a < b
sama_dengan = a == b
tidak_sama = a != b
lebih_besar_sama = a >= b
kurang_sama = a <= b

print("\nOPERASI PERBANDINGAN")
print("a > b =", lebih_besar)
print("a < b =", kurang_dari)
print("a == b =", sama_dengan)
print("a != b =", tidak_sama)
print("a >= b =", lebih_besar_sama)
print("a <= b =", kurang_sama)

print('''\nNote : Dari kode diatas, operasi perbandingan sangat berguna untuk membandingkan suatu variabel, terdapar 6 jenis
      Hasil dari variabel yang dibandingkan adalah boolean (true atau false)''')

print(f'{Fore.GREEN}\n4. Operasi Logika{Style.RESET_ALL}')
# and, or, not

x = True
y = False

logika_and = x and y
logika_or = x or y
logika_not_x = not x

print("\nOPERASI LOGIKA")
print("x =", x, ", y =", y)
print("x and y =", logika_and)
print("x or y =", logika_or)
print("not x =", logika_not_x)

print('''\nNote : Dari kode diatas, operasi logika pada python berbeda dengan bahasa pemrograman lainnya
      Jika di bahasa pemrograman lainnya menggunakan simbol && (and), || (or), dan ! (not)''')

print(f'{Fore.GREEN}\n5. Contoh penggunaan di dalam percabangan{Style.RESET_ALL}')
if a > b and b > 0:
   print("\nKondisi terpenuhi: a lebih besar dari b, dan b masih positif.")
else:
    print("\nKondisi tidak terpenuhi atau b <= 0.")

print('''\nNote : Dari kode diatas, semua operasi yang ada di python sangat berguna untuk pembentukan struktur percabangan (if-else)''')
# Out:
# 1. Pendeklarasian Variabel
# Nama = Budi
# Umur = 20
# Tinggi = 170.5 cm
# Mahasiswa = True
#
# Note : Dari kode diatas, deklarasi variabel pada python tidak memerlukan tipe data secara eksplisit
#       Python akan menyesuaikan tipe data sesuai nilai dari variabel tersebut
#
# 2. Operasi Aritmetika
#
# OPERASI ARITMETIKA
# a = 10 , b = 3
# Penjumlahan = 13
# Pengurangan = 7
# Perkalian = 30
# Pembagian = 3.3333333333333335
# Pembagian Bulat = 3
# Modulus = 1
# Pangkat = 1000
#
# Note : Dari kode diatas, operasi aritmatika pada python terdiri dari 7 jenis...masing-masing jenis
#       memiliki bentuk (operator) dan fungsi yang berbeda-beda sesuai dengan kebutuhan
#
# 3. Operasi Perbandingan
#
# OPERASI PERBANDINGAN
# a > b = True
# a < b = False
# a == b = False
# a != b = True
# a >= b = True
# a <= b = False
#
# Note : Dari kode diatas, operasi perbandingan sangat berguna untuk membandingkan suatu variabel, terdapar 6 jenis
# ...

# %% [markdown]
# Praktikum 03. Percabangan

# %%
print(f'{Fore.GREEN}1. IF Sederhana{Style.RESET_ALL}')
# Program hanya mengeksekusi blok jika kondisinya True

nilai = 85
print("Contoh IF Sederhana:")
if nilai > 80:
    print("Selamat! Anda lulus dengan nilai tinggi.\n")

print('''\nNote : Dari kode diatas, kode print yang didalam IF hanya akan tampil ketika kondisinya terpenuhi''')

print(f'{Fore.GREEN}\n2. IF-ELSE{Style.RESET_ALL}')
# Jika kondisi True, eksekusi blok if; jika False, eksekusi blok else

umur = 17
print("Contoh IF-ELSE:")
if umur >= 18:
    print("Anda sudah cukup umur untuk mendapatkan SIM.")
else:
    print("Anda belum cukup umur untuk mendapatkan SIM.\n")

    print('''\nNote : Dari kode diatas, jika umur lebih atau sama dengan 18, maka akan tampil pesan pertama (print pada if)
          Sedangkan jika umur kurang dari 18, maka pesan dalam if tidak akan tampil, melainkan pesan pada else yang akan tampil''')

print(f'{Fore.GREEN}\n3. IF-ELIF-ELSE{Style.RESET_ALL}')
# Menangani banyak kondisi secara berurutan.
# Jika ada kondisi yang terpenuhi, blok yang bersangkutan dieksekusi,
# lalu program melewati blok kondisi setelahnya.

hari = "Rabu"
print("Contoh IF-ELIF-ELSE:")
if hari == "Senin":
    print("Hari Senin - Saatnya kembali bekerja!")
elif hari == "Selasa":
    print("Hari Selasa - Jadwal rapat mingguan.")
elif hari == "Rabu":
    print("Hari Rabu - Ada diskon di beberapa toko.")
else:
    print("Hari lainnya - Atur jadwalmu dengan baik.\n")

print('''\nNote : Dari kode diatas, perbedaan antara IF-ELSE dan IF-ELIF-ELSE adalah pada IF-ELIF-ELSE, jika kondisi pertama terpenuhi
      maka program akan melewati kondisi selanjutnya, jika IF-ELSE program akan mengsekusi semua kondisi yang ada''')

print(f'{Fore.GREEN}\n4. IF Bersarang (Nested IF){Style.RESET_ALL}')
# Kondisi di dalam kondisi, biasa digunakan jika kita perlu
# memeriksa sub-kondisi setelah kondisi pertama terpenuhi.

suhu = 35
print("Contoh IF Bersarang (Nested IF):")
if suhu > 30:
    print("Cuaca cukup panas.")
    if suhu > 40:
        print("Bahkan sangat terik! Disarankan banyak minum air.")
    else:
        print("Masih relatif normal, tapi tetap jaga kesehatan.")
else:
    print("Cuaca sepertinya cukup sejuk.\n")

print('''\nNote : Dari kode diatas, if-else dapat berada didalam if lainnya, dan akan tereksekusi ketika semua kondisi dari if pertama dan
      if kedua terpenuhi, dan seterusnya''')

print(f'{Fore.GREEN}\n5. Menggabungkan Percabangan dengan Operasi Logika{Style.RESET_ALL}')
# Memeriksa beberapa kondisi sekaligus dengan and, or, not

nilai_teori = 75
nilai_praktik = 80
print("Contoh IF dengan Operasi Logika AND/OR:")
if nilai_teori >= 70 and nilai_praktik >= 70:
    print("Anda lulus karena nilai teori dan praktik memadai.")
elif nilai_teori < 70 and nilai_praktik < 70:
    print("Anda perlu meningkatkan nilai teori dan praktik.")
elif nilai_teori < 70:
    print("Anda perlu meningkatkan nilai teori.")
else:
    print("Anda perlu meningkatkan nilai praktik.\n")

print('''\nNote : Dari kode diatas, pada kondisi''')

print('''\nNote : Dari kode diatas, dalam penggunaan AND, jika salah satu kondisi tidak terpenuhi, maka kondisi tersebut akan dianggap
      false, sedangkan pada OR, jika salah satu kondisi terpenuhi, maka kondisi tersebut akan dianggap true''')

print(f'{Fore.GREEN}\n6. Penggunaan If Ternary (atau Conditional Expression){Style.RESET_ALL}')
# Bentuk ringkas: <hasil_if_true> if <kondisi> else <hasil_if_false>

angka = -5
print("Contoh If Ternary (Conditional Expression):")
status = "Positif" if angka > 0 else "Negatif atau Nol"
print("Angka =", angka, "=>", status)

print('''\nNote : Dari kode diatas, penulisan if else dapat disingkat dengan menggunakan if tenary, dimana hasilnya akan berbeda
      jika kondisi terpenuhi dan tidak terpenuhi''')
# Out:
# 1. IF Sederhana
# Contoh IF Sederhana:
# Selamat! Anda lulus dengan nilai tinggi.
#
#
# Note : Dari kode diatas, kode print yang didalam IF hanya akan tampil ketika kondisinya terpenuhi
#
# 2. IF-ELSE
# Contoh IF-ELSE:
# Anda belum cukup umur untuk mendapatkan SIM.
#
#
# Note : Dari kode diatas, jika umur lebih atau sama dengan 18, maka akan tampil pesan pertama (print pada if)
#           Sedangkan jika umur kurang dari 18, maka pesan dalam if tidak akan tampil, melainkan pesan pada else yang akan tampil
#
# 3. IF-ELIF-ELSE
# Contoh IF-ELIF-ELSE:
# Hari Rabu - Ada diskon di beberapa toko.
#
# Note : Dari kode diatas, perbedaan antara IF-ELSE dan IF-ELIF-ELSE adalah pada IF-ELIF-ELSE, jika kondisi pertama terpenuhi
#       maka program akan melewati kondisi selanjutnya, jika IF-ELSE program akan mengsekusi semua kondisi yang ada
#
# 4. IF Bersarang (Nested IF)
# Contoh IF Bersarang (Nested IF):
# Cuaca cukup panas.
# Masih relatif normal, tapi tetap jaga kesehatan.
#
# ...

# %% [markdown]
# Praktikum 04. Perulangan

# %%
# 1. FOR Loop dengan range()
print(f"{Fore.GREEN}1) FOR loop dengan range(){Style.RESET_ALL}")
for i in range(5):
    print("Perulangan ke-", i)
# range(5) menghasilkan nilai 0, 1, 2, 3, dan 4
# Sehingga perulangan akan berjalan sebanyak 5 kali

print('''\nNote : Dari kode diatas, mulainya perulangan dengan range() tidak dari angka 1 melainkan angka 0''')

print()  # pemisah output

# 2. FOR Loop untuk mengiterasi List
print(f"{Fore.GREEN}2) FOR loop mengiterasi list{Style.RESET_ALL}")
buah = ["apel", "mangga", "jeruk", "pisang"]
for item in buah:
    print("Buah:", item)
# Loop akan mengeksekusi setiap elemen dalam list "buah"
print('''\nNote : Dari kode diatas, print pada kode perulangan akan mengeksekusi semua buah yang ada dalam list''')
print()

# 3. WHILE Loop
print(f"{Fore.GREEN}3) WHILE loop sederhana{Style.RESET_ALL}")
count = 0
while count < 5:
    print("count =", count)
    count += 1  # increment
# Perulangan while terus dijalankan selama kondisi (count < 5) bernilai True
print('''\nNote : Dari kode diatas, while sering digunakan untuk perulangan yang tidak diketahui berapa kali perulangannya, jika kondisi
      sederhana dan ada batasnya, sering kali menggunakan for''')

print()

# 4. BREAK pada Loop
print(f"{Fore.GREEN}4) BREAK di dalam loop{Style.RESET_ALL}")
for i in range(10):
    if i == 3:
        print("Loop dihentikan pada i =", i)
        break  # mengakhiri loop saat i = 3
    print("i =", i)
# Keyword break langsung menghentikan keseluruhan perulangan

print('''\nNote : Dari kode diatas, loopingan akan berhenti ketika i nya sudah mencapai 3, karena ada keyword break yang akan menghentikan
      perulangan saat kondisi terpenuhi''')
print()

# 5. CONTINUE pada Loop
print(f"{Fore.GREEN}5) CONTINUE di dalam loop{Style.RESET_ALL}")
for i in range(5):

   if i == 2:
      print("Lewati i =", i, "dengan continue")

      continue  # melewati iterasi saat ini dan lanjut ke iterasi berikutnya
   print("i =", i)
# Saat i = 2, baris print("i =", i) tidak akan dieksekusi
print('''\nNote : Dari kode diatas, continue dapat berguna jika kita ingin skip beberapa kodingan di dalam perulangan, dan melanjutkan
      ke perulangan berikutnya''')

print()

# 6. NESTED Loop (Loop Bersarang)
print(f"{Fore.GREEN}6) NESTED loop{Style.RESET_ALL}")
for i in range(3):
    for j in range(2):
        print(f"i={i}, j={j}")
 # Loop luar (outer loop)
 # Loop dalam (inner loop)
# Pada setiap iterasi i, loop j akan berjalan dari 0 sampai 1
print('''\nNote : Dari kode diatas, loopingan yang dieksekusi seluruhnya adalah loop yang berada di dalam, jika loop dalam sudah
      selesai maka loop luar akan dijalankan''')

print()

# 7. Memanfaatkan ELSE pada Loop
print(f"{Fore.GREEN}7) ELSE pada loop for/while{Style.RESET_ALL}")
# Python memiliki fitur unik: blok else pada loop
# Blok else akan dieksekusi jika loop selesai tanpa di-break.

for x in range(3):
    print("x =", x)
else:
    print("Loop for telah selesai tanpa break.\n")

y = 0
while y < 3:
   print("y =", y)
   y += 1
else:
   print("Loop while telah selesai tanpa break.\n")
   print('''\nNote : Dari kode diatas, while loop dapat selesai tanpa break jika kondisi dalam while terpenuhi''')

# 8. PASS sebagai placeholder
print(f"{Fore.GREEN}\n8) PASS (placeholder){Style.RESET_ALL}")
for i in range(3):
   if i == 1:
      pass  # pass tidak melakukan apa-apa, digunakan sebagai placeholder
   print("i =", i)
print('''\nNote : Dari kode diatas, pass sangat berguna jika kita belum mengetahui isi dari blok kode tersebut, dan akan diisi nanti''')
# Out:
# 1) FOR loop dengan range()
# Perulangan ke- 0
# Perulangan ke- 1
# Perulangan ke- 2
# Perulangan ke- 3
# Perulangan ke- 4
#
# Note : Dari kode diatas, mulainya perulangan dengan range() tidak dari angka 1 melainkan angka 0
#
# 2) FOR loop mengiterasi list
# Buah: apel
# Buah: mangga
# Buah: jeruk
# Buah: pisang
#
# Note : Dari kode diatas, print pada kode perulangan akan mengeksekusi semua buah yang ada dalam list
#
# 3) WHILE loop sederhana
# count = 0
# count = 1
# count = 2
# count = 3
# count = 4
#
# Note : Dari kode diatas, while sering digunakan untuk perulangan yang tidak diketahui berapa kali perulangannya, jika kondisi
#       sederhana dan ada batasnya, sering kali menggunakan for
#
# 4) BREAK di dalam loop
# i = 0
# i = 1
# i = 2
# Loop dihentikan pada i = 3
#
# Note : Dari kode diatas, loopingan akan berhenti ketika i nya sudah mencapai 3, karena ada keyword break yang akan menghentikan
#       perulangan saat kondisi terpenuhi
#
# 5) CONTINUE di dalam loop
# i = 0
# ...

# %% [markdown]
#  Program untuk menghitung BMI (Body Mass Index)

# %%
# Buat fungsi untuk menghitung BMI
def Penghitung_BMI(berat, tinggi):
   #Ubah tinggi ke Meter
   tinggi_meter = tinggi / 100
   #masukkan rumus BMI kedalam variabel BMI
   BMI = berat/(tinggi_meter**2)
   return BMI # Kembalikan nilai BMI

# Buat program untuk mengambil input berat dan tinggi
def program_utama():
      print(f'{Fore.CYAN}===PROGRAM PENGHITUNG BMI (BODY MASS INDEX)==={Style.RESET_ALL}')
      berat = float(input("Masukkan Berat Badan (kg): "))
      tinggi = float(input("Masukkan Tinggi (cm): "))
      if tinggi < 3: # Cek apakah tinggi dalam bentuk meter atau centimeter
         print(f'{Fore.YELLOW}Tinggi harus dalam cm!!')
         tinggi = float(input("Masukkan Tinggi (cm): "))
      else:
         hasil_BMI = Penghitung_BMI(berat, tinggi)
         #  Buat percabangan untuk mengetahui kategori BMI
         if hasil_BMI < 18.5:
            print(f'Berat Badan: {berat:.0f} kg')
            print(f'Tinggi Badan: {tinggi:.0f} cm')
            print(f'Nilai BMI anda: {hasil_BMI:.2f}, Kategori: Underweight')
         elif hasil_BMI >= 18.5 and hasil_BMI <= 24.9:
            print(f'Berat Badan: {berat:.0f} kg')
            print(f'Tinggi Badan: {tinggi:.0f} cm')
            print(f'Nilai BMI anda: {hasil_BMI:.2f}, Kategori: Normal')
         elif hasil_BMI >= 25 and hasil_BMI <= 29.9:
            print(f'Berat Badan: {berat:.0f} kg')
            print(f'Tinggi Badan: {tinggi:.0f} cm')
            print(f'Nilai BMI anda: {hasil_BMI:.2f}, Kategori: Overweight')
         else:
            print(f'Berat Badan: {berat:.0f} kg')
            print(f'Tinggi Badan: {tinggi:.0f} cm')
            print(f'Nilai BMI anda: {hasil_BMI:.2f}, Tidak tergolong dalam kategori manapun')
      print(f'{Fore.GREEN}Program Selesai...{Style.RESET_ALL}')

if __name__ == "__main__":
   program_utama()
# Out:
# ===PROGRAM PENGHITUNG BMI (BODY MASS INDEX)===
# Berat Badan: 73 kg
# Tinggi Badan: 175 cm
# Nilai BMI anda: 23.84, Kategori: Normal
# Program Selesai...

# %% [markdown]
# Program yang mengecek apakah suatu bilangan genap, ganjil, atau prima

# %%
def check_prima(angka):
   if angka == 1:
      hasil = False
   elif angka == 2 or angka == 3:
      hasil = True
   else :
      for i in range(2, angka-1):
         check = angka % i
         if check == 0:
            hasil = False
            break
         else :
            hasil = True
   return hasil

def check_angka(angka):
   if angka % 2 == 0 and angka != 2:
      print(f'Angka: {angka} adalah Bilangan Genap')
   else:
      if check_prima(angka):
         print(f'Angka: {angka} adalah Bilangan Ganjil sekaligus Bilangan Prima')
      else:
         print(f'Angka: {angka} adalah Bilangan Ganjil')

def program_utama():
   print(f'{Fore.CYAN}===PROGRAM PENGECEK BILANGAN==={Style.RESET_ALL}')
   value_angka = int(input("Masukkan angka yang akan dicek: "))
   check_angka(value_angka)
   print(f'{Fore.GREEN}Program Selesai...{Style.RESET_ALL}')

if __name__ == "__main__":
   program_utama()
# Out:
# ===PROGRAM PENGECEK BILANGAN===
# Angka: 17 adalah Bilangan Ganjil sekaligus Bilangan Prima
# Program Selesai...
